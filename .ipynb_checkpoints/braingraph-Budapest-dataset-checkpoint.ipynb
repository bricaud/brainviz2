# %% [markdown]
# # Analysis of the brain connections

# %% [markdown]
# ## Introduction

# %% [markdown]
# We analyse here the brain connections provided on the website: http://pitgroup.org/connectome/

# %% [markdown]
# It is based on the following work:
#
# Balázs Szalkai, Csaba Kerepesi, Bálint Varga, Vince Grolmusz, The Budapest Reference Connectome Server v2.0, Neuroscience Letters, Vol. 595 (2015), Pages 60-62, http://dx.doi.org/10.1016/j.neulet.2015.03.071.
#
# Balázs Szalkai, Csaba Kerepesi, Bálint Varga, Vince Grolmusz, Parameterizable Consensus Connectomes from the Human Connectome Project: The Budapest Reference Connectome Server v3.0, , Cognitive Neurodynamics, (2016), http://dx.doi.org/10.1007/s11571-016-9407-z.

# %% [markdown]
# ## Data

# %% [markdown]
# CSV graph format
#
# * The first line of the CSV is a header line containing the field names.
# * Each of the following lines contains an edge.
# * The first four fields contain the indexes and names of the two connected regions of interest.
# * The next four fields contain the indexes and names of the parent regions in the 83-region atlas.
# * The last fields contain the number of containing graphs, then the mean and the median edge weight among those graphs which contain the specific edge.
# * The weight of an edge is calculated by the formula n/L, where n is the number of tracks between the two regions, and L is the average length of those tracks.

# %% [markdown]
# They unified the connectomes of 477 people (computed from MRI datasets of the Human Connectome Project) into a reference brain graph. The edge confidence (9th column) is the number of patient having this connection.

# %%
import pandas as pd
import networkx as nx

# %%
df = pd.read_csv("budapest_connectome_3.0_5_0_median.csv",sep=";")

# %%
df
# Out:
#        id node1  id node2                  name node1  \
# 0           559       559  lh.rostralmiddlefrontal_15
# 1           559       565  lh.rostralmiddlefrontal_15
# 2           559       560  lh.rostralmiddlefrontal_15
# 3           559      1004  lh.rostralmiddlefrontal_15
# 4           559       767  lh.rostralmiddlefrontal_15
# 5           559       785  lh.rostralmiddlefrontal_15
# 6           559       580  lh.rostralmiddlefrontal_15
# 7           559       730  lh.rostralmiddlefrontal_15
# 8           559       609  lh.rostralmiddlefrontal_15
# 9           559       587  lh.rostralmiddlefrontal_15
# 10          559       582  lh.rostralmiddlefrontal_15
# 11          559       601  lh.rostralmiddlefrontal_15
# 12          559       779  lh.rostralmiddlefrontal_15
# 13          559       633  lh.rostralmiddlefrontal_15
# 14          559      1011  lh.rostralmiddlefrontal_15
# 15          559       634  lh.rostralmiddlefrontal_15
# 16          559       584  lh.rostralmiddlefrontal_15
# 17          559       697  lh.rostralmiddlefrontal_15
# 18          559       578  lh.rostralmiddlefrontal_15
# 19          559       700  lh.rostralmiddlefrontal_15
# 20          559       695  lh.rostralmiddlefrontal_15
# 21          559       769  lh.rostralmiddlefrontal_15
# 22          559      1010  lh.rostralmiddlefrontal_15
# 23          559       572  lh.rostralmiddlefrontal_15
# 24          559       689  lh.rostralmiddlefrontal_15
# 25          559       691  lh.rostralmiddlefrontal_15
# 26          559       833  lh.rostralmiddlefrontal_15
# 27          559       571  lh.rostralmiddlefrontal_15
# 28          559       825  lh.rostralmiddlefrontal_15
# 29          559       771  lh.rostralmiddlefrontal_15
# ...         ...       ...                         ...
# 73513       945       977        lh.middletemporal_13
# 73514       945       946        lh.middletemporal_13
# 73515       945       965        lh.middletemporal_13
# 73516       945       966        lh.middletemporal_13
# 73517       945      1013        lh.middletemporal_13
# 73518       945       986        lh.middletemporal_13
# 73519       945       957        lh.middletemporal_13
# 73520       945      1008        lh.middletemporal_13
# 73521       945       994        lh.middletemporal_13
# 73522       945       960        lh.middletemporal_13
# 73523       945      1014        lh.middletemporal_13
# 73524       945       980        lh.middletemporal_13
# 73525       945       981        lh.middletemporal_13
# 73526       945       962        lh.middletemporal_13
# 73527       945       954        lh.middletemporal_13
# 73528       945       971        lh.middletemporal_13
# 73529       945       952        lh.middletemporal_13
# 73530       945      1010        lh.middletemporal_13
# 73531       945       958        lh.middletemporal_13
# 73532       945       948        lh.middletemporal_13
# 73533       945       983        lh.middletemporal_13
# 73534       945       953        lh.middletemporal_13
# 73535       945       950        lh.middletemporal_13
# 73536       945       951        lh.middletemporal_13
# 73537       945       956        lh.middletemporal_13
# 73538       945       976        lh.middletemporal_13
# 73539       945       949        lh.middletemporal_13
# 73540       945       947        lh.middletemporal_13
# 73541       945      1000        lh.middletemporal_13
# 73542       945       945        lh.middletemporal_13
#
#                           name node2  parent id node1  parent id node2  \
# 0         lh.rostralmiddlefrontal_15               48               48
# 1         lh.rostralmiddlefrontal_22               48               48
# 2         lh.rostralmiddlefrontal_13               48               48
# 3                        lh.insula_4               48               75
# 4             lh.superiorparietal_24               48               59
# 5              lh.superiorparietal_6               48               59
# 6          lh.rostralmiddlefrontal_3               48               48
# 7                   lh.postcentral_8               48               57
# 8              lh.superiorfrontal_20               48               49
# 9              lh.superiorfrontal_14               48               49
# 10        lh.rostralmiddlefrontal_25               48               48
# 11             lh.superiorfrontal_21               48               49
# 12            lh.superiorparietal_16               48               59
# 13          lh.caudalmiddlefrontal_5               48               50
# 14                     Left-Pallidum               48               79
# 15          lh.caudalmiddlefrontal_3               48               50
# 16             lh.superiorfrontal_11               48               49
# 17      lh.caudalanteriorcingulate_3               48               54
# 18         lh.rostralmiddlefrontal_7               48               48
# 19           lh.posteriorcingulate_8               48               55
# 20      lh.caudalanteriorcingulate_1               48               54
# 21            lh.superiorparietal_27               48               59
# 22                      Left-Putamen               48               78
# 23        lh.rostralmiddlefrontal_21               48               48
# 24     lh.rostralanteriorcingulate_4               48               53
# 25     lh.rostralanteriorcingulate_2               48               53
# 26                   lh.precuneus_11               48               61
# 27        lh.rostralmiddlefrontal_10               48               48
# 28                    lh.precuneus_4               48               61
# 29            lh.superiorparietal_13               48               59
# ...                              ...              ...              ...
# 73513         lh.superiortemporal_23               71               73
# 73514            lh.middletemporal_8               71               71
# 73515         lh.superiortemporal_24               71               73
# 73516         lh.superiortemporal_18               71               73
# 73517               Left-Hippocampus               71               81
# 73518          lh.superiortemporal_2               71               73
# 73519                  lh.bankssts_2               71               72
# 73520           Left-Thalamus-Proper               71               76
# 73521                   lh.insula_12               71               75
# 73522                  lh.bankssts_5               71               72
# 73523                  Left-Amygdala               71               82
# 73524          lh.superiortemporal_5               71               73
# 73525         lh.superiortemporal_10               71               73
# 73526         lh.superiortemporal_20               71               73
# 73527           lh.middletemporal_12               71               71
# 73528          lh.superiortemporal_9               71               73
# 73529            lh.middletemporal_2               71               71
# 73530                   Left-Putamen               71               78
# 73531                  lh.bankssts_6               71               72
# 73532            lh.middletemporal_5               71               71
# 73533         lh.superiortemporal_22               71               73
# 73534            lh.middletemporal_4               71               71
# 73535            lh.middletemporal_9               71               71
# 73536           lh.middletemporal_15               71               71
# 73537                  lh.bankssts_3               71               72
# 73538          lh.superiortemporal_8               71               73
# 73539           lh.middletemporal_11               71               71
# 73540           lh.middletemporal_14               71               71
# 73541                   lh.insula_13               71               75
# 73542           lh.middletemporal_13               71               71
#
#                  parent name node1                parent name node2  \
# 0      ctx-lh-rostralmiddlefrontal      ctx-lh-rostralmiddlefrontal
# 1      ctx-lh-rostralmiddlefrontal      ctx-lh-rostralmiddlefrontal
# 2      ctx-lh-rostralmiddlefrontal      ctx-lh-rostralmiddlefrontal
# 3      ctx-lh-rostralmiddlefrontal                    ctx-lh-insula
# 4      ctx-lh-rostralmiddlefrontal          ctx-lh-superiorparietal
# 5      ctx-lh-rostralmiddlefrontal          ctx-lh-superiorparietal
# 6      ctx-lh-rostralmiddlefrontal      ctx-lh-rostralmiddlefrontal
# 7      ctx-lh-rostralmiddlefrontal               ctx-lh-postcentral
# 8      ctx-lh-rostralmiddlefrontal           ctx-lh-superiorfrontal
# 9      ctx-lh-rostralmiddlefrontal           ctx-lh-superiorfrontal
# 10     ctx-lh-rostralmiddlefrontal      ctx-lh-rostralmiddlefrontal
# 11     ctx-lh-rostralmiddlefrontal           ctx-lh-superiorfrontal
# 12     ctx-lh-rostralmiddlefrontal          ctx-lh-superiorparietal
# 13     ctx-lh-rostralmiddlefrontal       ctx-lh-caudalmiddlefrontal
# 14     ctx-lh-rostralmiddlefrontal                    Left-Pallidum
# 15     ctx-lh-rostralmiddlefrontal       ctx-lh-caudalmiddlefrontal
# 16     ctx-lh-rostralmiddlefrontal           ctx-lh-superiorfrontal
# 17     ctx-lh-rostralmiddlefrontal   ctx-lh-caudalanteriorcingulate
# 18     ctx-lh-rostralmiddlefrontal      ctx-lh-rostralmiddlefrontal
# 19     ctx-lh-rostralmiddlefrontal        ctx-lh-posteriorcingulate
# 20     ctx-lh-rostralmiddlefrontal   ctx-lh-caudalanteriorcingulate
# 21     ctx-lh-rostralmiddlefrontal          ctx-lh-superiorparietal
# 22     ctx-lh-rostralmiddlefrontal                     Left-Putamen
# 23     ctx-lh-rostralmiddlefrontal      ctx-lh-rostralmiddlefrontal
# 24     ctx-lh-rostralmiddlefrontal  ctx-lh-rostralanteriorcingulate
# 25     ctx-lh-rostralmiddlefrontal  ctx-lh-rostralanteriorcingulate
# 26     ctx-lh-rostralmiddlefrontal                 ctx-lh-precuneus
# 27     ctx-lh-rostralmiddlefrontal      ctx-lh-rostralmiddlefrontal
# 28     ctx-lh-rostralmiddlefrontal                 ctx-lh-precuneus
# 29     ctx-lh-rostralmiddlefrontal          ctx-lh-superiorparietal
# ...                            ...                              ...
# 73513        ctx-lh-middletemporal          ctx-lh-superiortemporal
# 73514        ctx-lh-middletemporal            ctx-lh-middletemporal
# 73515        ctx-lh-middletemporal          ctx-lh-superiortemporal
# 73516        ctx-lh-middletemporal          ctx-lh-superiortemporal
# 73517        ctx-lh-middletemporal                 Left-Hippocampus
# 73518        ctx-lh-middletemporal          ctx-lh-superiortemporal
# 73519        ctx-lh-middletemporal                  ctx-lh-bankssts
# 73520        ctx-lh-middletemporal             Left-Thalamus-Proper
# 73521        ctx-lh-middletemporal                    ctx-lh-insula
# 73522        ctx-lh-middletemporal                  ctx-lh-bankssts
# 73523        ctx-lh-middletemporal                    Left-Amygdala
# 73524        ctx-lh-middletemporal          ctx-lh-superiortemporal
# 73525        ctx-lh-middletemporal          ctx-lh-superiortemporal
# 73526        ctx-lh-middletemporal          ctx-lh-superiortemporal
# 73527        ctx-lh-middletemporal            ctx-lh-middletemporal
# 73528        ctx-lh-middletemporal          ctx-lh-superiortemporal
# 73529        ctx-lh-middletemporal            ctx-lh-middletemporal
# 73530        ctx-lh-middletemporal                     Left-Putamen
# 73531        ctx-lh-middletemporal                  ctx-lh-bankssts
# 73532        ctx-lh-middletemporal            ctx-lh-middletemporal
# 73533        ctx-lh-middletemporal          ctx-lh-superiortemporal
# 73534        ctx-lh-middletemporal            ctx-lh-middletemporal
# 73535        ctx-lh-middletemporal            ctx-lh-middletemporal
# 73536        ctx-lh-middletemporal            ctx-lh-middletemporal
# 73537        ctx-lh-middletemporal                  ctx-lh-bankssts
# 73538        ctx-lh-middletemporal          ctx-lh-superiortemporal
# 73539        ctx-lh-middletemporal            ctx-lh-middletemporal
# 73540        ctx-lh-middletemporal            ctx-lh-middletemporal
# 73541        ctx-lh-middletemporal                    ctx-lh-insula
# 73542        ctx-lh-middletemporal            ctx-lh-middletemporal
#
#        edge confidence  edge weight(med nof)
# 0                  112                   4.0
# 1                  268                   7.0
# 2                  271                   6.0
# 3                  117                   8.0
# 4                    9                   1.0
# 5                    8                   7.5
# 6                   47                   3.0
# 7                    5                   4.0
# 8                    9                   2.0
# 9                   23                   1.0
# 10                   9                   3.0
# 11                  36                   4.5
# 12                   8                   2.0
# 13                  44                   9.5
# 14                  48                   5.0
# 15                 132                  12.0
# 16                   5                  11.0
# 17                  34                   6.5
# 18                  95                   7.0
# 19                   6                  12.0
# 20                  84                   8.5
# 21                  14                  18.0
# 22                 187                  27.0
# 23                  34                   3.0
# 24                  14                   2.0
# 25                  30                   3.0
# 26                   7                   9.0
# 27                  40                   3.5
# 28                   5                  12.0
# 29                   8                  12.0
# ...                ...                   ...
# 73513                8                   1.5
# 73514              164                   6.0
# 73515                8                  16.5
# 73516               14                   2.5
# 73517              122                  11.0
# 73518                7                   6.0
# 73519              220                   8.0
# 73520                9                   7.0
# 73521                5                   8.0
# 73522                5                   4.0
# 73523                5                   3.0
# 73524               23                   7.0
# 73525               10                   7.0
# 73526                5                   3.0
# 73527               17                   2.0
# 73528               35                   3.0
# 73529               40                   5.5
# 73530                5                   6.0
# 73531              208                   8.0
# 73532               87                   7.0
# 73533                8                   2.0
# 73534               17                   5.0
# 73535              187                  15.0
# 73536               30                   2.0
# 73537               22                   4.5
# 73538               13                   5.0
# 73539               46                   6.5
# 73540              265                  12.0
# 73541                8                   5.0
# 73542              167                   4.0
#
# [73543 rows x 10 columns]

# %% [markdown]
# ## Connectome between the 83 brain regions

# %% [markdown]
# Define the function to build the graph:

# %%
def node_info(node):
    """ Extract information from the row of the dataframe to attach to the nodes."""
    if "ctx-" in node: # in the cortex
        node_ctx = 1
        if "lh-" in node:
            node_lh = 1
        else:
            node_lh = 0
        node_name = node[7:]
    else: # subcortical
        node_ctx = 0
        if "Left" in node:
            node_lh = 1
        elif "Right" in node:
            node_lh = 0
        else:
            node_lh = 2 # brainstem
        node_name = node
    return node_name,node_ctx,node_lh

# %%
def create_graph(df,threshold):
    """ Create the graph of brain connections from the dataframe
    
    df is the dataframe containing the connections
    threshold is the minimal number of patients having this connection
    
    """
    G = nx.Graph()
    for idx,row in df.iterrows():
        node1 = row["parent name node1"]
        node_name,node_ctx,node_lh = node_info(node1)
        if node1 not in G:
            G.add_node(node1,name=node_name,ctx=node_ctx,hemisphere=node_lh)
        node2 = row["parent name node2"]
        node_name,node_ctx,node_lh = node_info(node2)
        if node2 not in G:
            G.add_node(node2,name=node_name,ctx=node_ctx,hemisphere=node_lh)
        if row["edge confidence"]>threshold:
            if G.has_edge(node1,node2):
                G[node1][node2]["weight"]+=1
            else:
                G.add_edge(node1,node2,weight=1)
    deg = nx.degree(G)
    nx.set_node_attributes(G,'degree',deg)
    print("Nb of edges: {}, nb of nodes: {}.".format(G.size(),len(G.nodes())))
    return G

# %% [markdown]
# ## Process and save the graph

# %%
import json
from networkx.readwrite import json_graph

# %% [markdown]
#  Graph with connections between 2 regions if at least 2 patients of the dataset have the connections between these regions.

# %%
G = create_graph(df,threshold=2)
# Out:
# Nb of edges: 1605, nb of nodes: 83.

# %%
# write json formatted data
data = json_graph.node_link_data(G) # node-link format to serialize
s = json.dumps(data)
# write json
with open('braingraph.json','w') as f:
    f.write(s)
print('Wrote node-link JSON data')
# Out:
# Wrote node-link JSON data

# %% [markdown]
#  Graph with connections between 2 regions if at least 400 patients of the dataset have the connections between these regions.

# %%
G = create_graph(df,threshold=400)
# Out:
# Nb of edges: 334, nb of nodes: 83.

# %%
# write json formatted data
data = json_graph.node_link_data(G) # node-link format to serialize
s = json.dumps(data)
# write json
with open('braingraph_lessconnect.json','w') as f:
    f.write(s)
print('Wrote node-link JSON data')
# Out:
# Wrote node-link JSON data

# %% [markdown]
#  Graph with connections between 2 regions if at least 200 patients of the dataset have the connections between these regions.

# %%
G = create_graph(df,threshold=200)
# Out:
# Nb of edges: 677, nb of nodes: 83.

# %%
# write json formatted data
data = json_graph.node_link_data(G) # node-link format to serialize
s = json.dumps(data)
# write json
with open('braingraph_mediumconnect.json','w') as f:
    f.write(s)
print('Wrote node-link JSON data')
# Out:
# Wrote node-link JSON data
